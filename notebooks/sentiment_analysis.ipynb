# %%
from settings import PATH_TO_DATA

from data_loader import load_polemo_no_segm_file, load_tagger_preprocesses_json_file, load_train_test_idx_file
from sentiment_model.sentiment_model import SentimentModel
from clarin_api_wrapper.wcrft2_wrapper import Wcrft2Wrapper
from settings import PATH_TO_DATA
from sklearn.metrics.classification import accuracy_score, recall_score, precision_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

from data_loader import POL_EMO_CLASSES_TO_INDEXES

POL_EMO_INDEXES_TO_CLASSES = {value: key for key, value in POL_EMO_CLASSES_TO_INDEXES.items()}

# %% [markdown]
# # Przykład predykcji

# %% [markdown]
# Wczytanie treningowego zbioru danych:

# %%
train_data = load_polemo_no_segm_file("plemo2.0-no-segm.txt")
train_data.columns = ["text", "label"]

# %% [markdown]
# Wczytanie stałęgo podziału na zbiór treningowy i testowy. Podział zapisany w postaci indexów do osbnego pliku .pkl

# %%
train_idx, test_idx = load_train_test_idx_file(f"{PATH_TO_DATA}/train_test_idx.pkl")

# %%
def visualize_class_distribution(data, title):
    data = data.copy()
    data["label"] = data["label"].apply(lambda x: POL_EMO_INDEXES_TO_CLASSES[x])
    groupped = data.groupby(['label']).count()
    labels = groupped.index.values
    values = groupped.values[:, 0]
    
    fig = plt.figure(figsize=(15, 8))
    
    x_data = np.arange(len(labels))
    
    y_data = values
    
    x = labels
    x_ticks = x_data
    plt.bar(x_data, values, tick_label=labels)
    plt.title(title, fontsize=20)
    plt.ylabel("Number of instances")
    plt.xlabel("label")
    
    xlocs, xlabs = plt.xticks()
    
    for i, v in enumerate(values):
        plt.text(xlocs[i] - 0.10, v + 0.03, str(round(v, 5)), color='black', fontsize=15)
    
    plt.show()
        
visualize_class_distribution(train_data, "all_data")
visualize_class_distribution(train_data.iloc[train_idx,:], "train_data")
visualize_class_distribution(train_data.iloc[test_idx,:], "test_data")

# %% [markdown]
# Wczytanie wyników taggera na zbiorze treningowym (zrobione raz żaby nie powtarzać długotrwałego przetwarzania kilkukrotnie):

# %%
tagger = "krnnt"

preprocessed_data = load_tagger_preprocesses_json_file(f"{PATH_TO_DATA}/taggers_output/{tagger}/plemo_no_segm_data.json")

# %% [markdown]
# Podział zbioru oraz odpowiedzi taggera na zbiór treningowy walidacyjny oraz na zdania i ich etykiety.

# %%
x_data, y_data = train_data.values[:, 0], train_data.values[:, 1].astype(int)
x_train, y_train = preprocessed_data[train_idx], y_data[train_idx]
x_test, y_test = preprocessed_data[test_idx], y_data[test_idx]

preprocessed_train, preprocessed_test = preprocessed_data[train_idx], preprocessed_data[test_idx]

# %% [markdown]
# Uczenie modelu (Naiwny Bayes z cechami zakodowanymi w postaci Bag of Words)

# %%
model = SentimentModel(tagger_wrapper=Wcrft2Wrapper())
model.fit(preprocessed_train, y_train, part_of_speech="verb", tagger_preprocessed=True)
# Out:
# (7459, 7083)
# Got lematized texts

# %% [markdown]
# Wynik predykcji (accuracy)

# %%
y_pred = model.predict(x_test, part_of_speech="verb", tagger_preprocessed=True, sentence_level=False)

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred, average='macro')}")
print(f"Precision: {precision_score(y_test, y_pred, average='macro')}")
print(f"FMeasure: {f1_score(y_test, y_pred, average='macro')}")
# Out:
# Accuracy: 0.6386058981233244
# Recall: 0.4144595337697577
# Precision: 0.42386826549389095
# FMeasure: 0.39399462381873773

# %%
labels = list(POL_EMO_CLASSES_TO_INDEXES.keys())

#confusion_matrix(y_train, y_train_pred)
actual = [labels[i] for i in y_test]
predicted = [labels[i] for i in y_pred]
y_actu_s = pd.Series(actual, name='Actual')
y_pred_s = pd.Series(predicted, name='Predicted')

crosstab = pd.crosstab(y_actu_s, y_pred_s)
crosstab
# Out:
# Predicted  amb  minus_m  minus_s  plus_m  plus_s  zero
# Actual
# amb          2       58        0      47       8     3
# minus_m      3      575        3     100       7     4
# minus_s      1       60        0      34       3     3
# plus_m       2      107        0     388      15     5
# plus_s       2       79        1      82       9     5
# zero         0       28        0      13       1   217

# %%
wrong_idx = np.where(y_actu_s != y_pred_s)[0]

for i in range(len(wrong_idx[:10])):
    index = wrong_idx[i]
    text, true_label = train_data.iloc[index].values
    print(f"true: {POL_EMO_INDEXES_TO_CLASSES[true_label]} pred: {POL_EMO_INDEXES_TO_CLASSES[y_pred[i]]}")
    print(text)
    print("------------------------")
# Out:
# true: plus_s pred: minus_m
# Gańcza Szermierka Moze być/Polecam [/b] Pan Gańcza nie jest typowym trenerem co wrzeszczy na studentów, ale bardziej miłym starszym panem, choc jego kondycja pozostanie obiektem niedoścignionym dla wielu. Rozgrzewka bardzo wyczerpująca, ale sa elementy jogi. Ostre rozciąganie. Szermierka to bardzo ciekawy sport, a Pan Gańcza potrafi go nauczyc. Ocena za obecności.
# ------------------------
# true: plus_s pred: minus_m
# Kotarba Wiesław, Prof. Informacja patentowa Ocena : Spoko[/b] Przedmiot nudny jak cholera, mimo, ze pierwszy wykład był dość ciekawy. Mozna sobie pospać na zajęciach. Do tego chyba nie sprawdza obecności. Na zaliczenie praca lub kolokwium. Można ściagać z opracowanych pytań. Human do odbębnienia.
# ------------------------
# true: amb pred: minus_m
# Borkowski A, mgr. inż. Miernictwo Elektroniczne (laboratorium) Ocena: Ujdzie, od biedy :)[/b] Ten koles nic nie wie z Miernictwa. Dość sympatyczny, chodz zwraca sprawka cały czas :/. Raczej nic sie nie nauczysz z tego przedmiotu, bo Pan Borkowski nie wytłumaczy nic "Wszys
# ------------------------
# true: plus_s pred: plus_s
# Popko Ewa, dr hab. fizyka (laboratorium) polecam [/b] W sumie pani Ewa okazało sie calkiem spoko. Nie bylo kartkowek, ale za to pytala. Pytania byly raczej z instrukcji albo z pytan umieszczonych na sronie instytutu fizyki, czasami tylko zdarzylo jej sie zadac jakies kosmiczne pytanie. Co do cwiczen, to nie zawsze wiedziala o co chodzi w danym cwiczeniu, ale i tak mimo wszystko bylo wporzadku. Sprawozdania nie oceniala nizej niz 4 (przynajmniej tak bylo u mnie), ale lubiala dawac je do poprawki. Jedynie ostatnie sprawka (jezeli nie udalo sie oddac przed odrobkami) nie dawala do poprawki ale tez oceny byly nizsze nawet 3. Na odrobki wysylala jak musiała.
# ------------------------
# true: minus_m pred: minus_m
# dr Magiera nalezy do ludzi, którzy bardzo się nudzą i dla rozrywki utrudnia życie innym. Czasami robil kartkowki, czasami nie. nie było zadnego schematu. niezaliczenie kartkowki nie równało się wyleceniem z zajęc, ale tez zaliczenie jej nie dawało zadnych profitów. dr Leon niezauwaza błednych obliczeń, za to bardzo nie lubi nierównych tabelek, albo niewytłuszczonych wyników. jest miłosnikiem programu Derive, wiec można sobie nabić plusy korzystając z tegóż. osobiście nie polecam, ale też nie odstraszam. Dziwak i tyle.
# ------------------------
# true: plus_s pred: minus_m
# Niewiele mogę powiedzieć, bo widziałem tego pana 3 razy - 2 razy na kolokwiach i raz jak dawał mi wpis do indeksu. Na kolokwiach można sciągać ile wlezie, ba! mozna nawet przyjsc z własnym korepetytorem i znajomymi, zeby bylo przyjemniej. Zadania banalne. polecam
# ------------------------
# true: plus_s pred: minus_m
# Dużo wymaga, ale bardzo uczciwy i przyjazny studentom. Warto chodzić na konsultacje. Docenia postępy i zaangażowanie. Polecam.
# ------------------------
# true: amb pred: minus_m
# Zgadzam się. Pan Górniak jest wymagający ale daje raczej standardowe zadania ze skryptu. Ma dobrą pamięć więc jeżeli chodziło się na wykłady i będzie wahać się ocena wtedy łaskawiej spojrzy na ludka :)
# ------------------------
# true: amb pred: zero
# Ćwiczenia z tą Panią trochę się dłużą, wymagania chyba raczej nieszczególnie wysokie, chociaż w ciagu semestru trzeba zaliczyć wszystkie kartówki, napisać wszystkie prace i zaliczyć jedno kolokwium. Troche tego jest... plusem jest to, że nie trzeba chodzić na wszystkie zajęcia - ja byłem mniej więcej na połowie. Przy wystawianiu oceny niby patrzy na obecności, ale raczej nie obniża za bardzo.
# ------------------------
# true: plus_m pred: minus_m
# Niemiecki A1 Cóż... Pierwszy kurs językowy i pozytywne zaskoczenie :) Pani naprawdę zna sie na tym co robi i ma odpowiednie podejście do studenta. Co powiecie na cukierki dla calej grupy za zrobioną pracę domową? Albo czekoladę za 100% obecność? :D Dla mnie bomba... Niby dozwolone 2 nieobecności ale... Ale coś za coś... ;) Pani pędzi do przodu z materialem jakby ją cały Wehrmacht gonił ;) Przez semestr przerobilismy okolo 3 podrecznikow + kserówki... Za to poziom A2/E juz mi nie jest straszny, zwlaszcza jesli chodzi o slowka. No i pamieta imiona wszystkich uczestników juz po 1 zajeciach, co sie nieczesto zdarza. Na koniec test z calosci materialu (ale raczej na myslenie niż na wykucie słówek), ale na ocenę końcową wpływają głównie obecnosci. Jak ktoś chce się nauczyć to szczerze polecam :D
# ------------------------

# %% [markdown]
# # Pzykład predykcji przy analize tekstów na poziomie zdań

# %%
x_train, y_train = preprocessed_data[train_idx], y_data[train_idx]
x_test, y_test = x_data[test_idx], y_data[test_idx]

model = SentimentModel(tagger_wrapper=Wcrft2Wrapper())
model.fit(preprocessed_train, y_train, part_of_speech=None, tagger_preprocessed=True)

y_pred = model.predict(x_test, part_of_speech=None, tagger_preprocessed=False, sentence_level=True)
# Out:
# (7459, 39833)
# Got lematized texts
# Got data from tagger
# 0
# Got data from tagger
# 1
# Got data from tagger
# 2
# Got data from tagger
# 3
# Got data from tagger
# 4
# Got data from tagger
# 5
# Got data from tagger
# 6
# Got data from tagger
# 7
# Got data from tagger
# 8
# Got data from tagger
# 9
# Got data from tagger
# 10
# Got data from tagger
# 11
# Got data from tagger
# 12
# Got data from tagger
# 13
# Got data from tagger
# 14
# Got data from tagger
# 15
# Got data from tagger
# 16
# Got data from tagger
# 17
# Got data from tagger
# 18
# Got data from tagger
# 19
# Got data from tagger
# 20
# Got data from tagger
# 21
# Got data from tagger
# 22
# Got data from tagger
# 23
# Got data from tagger
# 24
# Got data from tagger
# 25
# Got data from tagger
# 26
# Got data from tagger
# 27
# Got data from tagger
# 28
# Got data from tagger
# 29
# Got data from tagger
# 30
# Got data from tagger
# 31
# Got data from tagger
# 32
# Got data from tagger
# 33
# Got data from tagger
# 34
# Got data from tagger
# 35
# Got data from tagger
# 36
# Got data from tagger
# 37
# Got data from tagger
# 38
# Got data from tagger
# 39
# Got data from tagger
# 40
# Got data from tagger
# 41
# Got data from tagger
# 42
# Got data from tagger
# 43
# Got data from tagger
# 44
# Got data from tagger
# 45
# Got data from tagger
# 46
# Got data from tagger
# 47
# Got data from tagger
# 48
# Got data from tagger
# 49
# Got data from tagger
# 50
# Got data from tagger
# 51
# Got data from tagger
# 52
# Got data from tagger
# 53
# Got data from tagger
# 54
# Got data from tagger
# 55
# Got data from tagger
# 56
# Got data from tagger
# 57
# Got data from tagger
# 58
# Got data from tagger
# 59
# Got data from tagger
# 60
# Got data from tagger
# 61
# Got data from tagger
# 62
# Got data from tagger
# 63
# Got data from tagger
# 64
# Got data from tagger
# 65
# Got data from tagger
# 66
# Got data from tagger
# 67
# Got data from tagger
# 68
# Got data from tagger
# 69
# Got data from tagger
# 70
# Got data from tagger
# 71
# Got data from tagger
# 72
# Got data from tagger
# 73
# Got data from tagger
# 74
# Got data from tagger
# 75
# Got data from tagger
# 76
# Got data from tagger
# 77
# Got data from tagger
# 78
# Got data from tagger
# 79
# Got data from tagger
# 80
# Got data from tagger
# 81
# Got data from tagger
# 82
# Got data from tagger
# 83
# Got data from tagger
# 84
# Got data from tagger
# 85
# Got data from tagger
# 86
# Got data from tagger
# 87
# Got data from tagger
# 88
# Got data from tagger
# 89
# Got data from tagger
# 90
# Got data from tagger
# 91
# Got data from tagger
# 92
# Got data from tagger
# 93
# Got data from tagger
# 94
# Got data from tagger
# 95
# Got data from tagger
# 96
# Got data from tagger
# 97
# Got data from tagger
# 98
# Got data from tagger
# 99
# Got data from tagger
# 100
# Got data from tagger
# 101
# Got data from tagger
# 102
# Got data from tagger
# 103
# Got data from tagger
# 104
# Got data from tagger
# 105
# Got data from tagger
# 106
# Got data from tagger
# 107
# Got data from tagger
# 108
# Got data from tagger
# 109
# Got data from tagger
# 110
# Got data from tagger
# 111
# Got data from tagger
# 112
# Got data from tagger
# 113
# Got data from tagger
# 114
# Got data from tagger
# 115
# Got data from tagger
# 116
# Got data from tagger
# 117
# Got data from tagger
# 118
# Got data from tagger
# 119
# Got data from tagger
# 120
# Got data from tagger
# 121
# Got data from tagger
# 122
# Got data from tagger
# 123
# Got data from tagger
# 124
# Got data from tagger
# 125
# Got data from tagger
# 126
# Got data from tagger
# 127
# Got data from tagger
# 128
# Got data from tagger
# 129
# Got data from tagger
# 130
# Got data from tagger
# 131
# Got data from tagger
# 132
# Got data from tagger
# 133
# Got data from tagger
# 134
# Got data from tagger
# 135
# Got data from tagger
# 136
# Got data from tagger
# 137
# Got data from tagger
# 138
# Got data from tagger
# 139
# Got data from tagger
# 140
# Got data from tagger
# 141
# Got data from tagger
# 142
# Got data from tagger
# 143
# Got data from tagger
# 144
# Got data from tagger
# 145
# Got data from tagger
# 146
# Got data from tagger
# 147
# Got data from tagger
# 148
# Got data from tagger
# 149
# Got data from tagger
# 150
# Got data from tagger
# 151
# Got data from tagger
# 152
# Got data from tagger
# 153
# Got data from tagger
# 154
# Got data from tagger
# 155
# Got data from tagger
# 156
# Got data from tagger
# 157
# Got data from tagger
# 158
# Got data from tagger
# 159
# Got data from tagger
# 160
# Got data from tagger
# 161
# Got data from tagger
# 162
# Got data from tagger
# 163
# Got data from tagger
# 164
# Got data from tagger
# 165
# Got data from tagger
# 166
# Got data from tagger
# 167
# Got data from tagger
# 168
# Got data from tagger
# 169
# Got data from tagger
# 170
# Got data from tagger
# 171
# Got data from tagger
# 172
# Got data from tagger
# 173
# Got data from tagger
# 174
# Got data from tagger
# 175
# Got data from tagger
# 176
# Got data from tagger
# 177
# Got data from tagger
# 178
# Got data from tagger
# 179
# Got data from tagger
# 180
# Got data from tagger
# 181
# Got data from tagger
# 182
# Got data from tagger
# 183
# Got data from tagger
# 184
# Got data from tagger
# 185
# Got data from tagger
# 186
# Got data from tagger
# 187
# Got data from tagger
# 188
# Got data from tagger
# 189
# Got data from tagger
# 190
# Got data from tagger
# 191
# Got data from tagger
# 192
# Got data from tagger
# 193
# Got data from tagger
# 194
# Got data from tagger
# 195
# Got data from tagger
# 196
# Got data from tagger
# 197
# Got data from tagger
# 198
# Got data from tagger
# 199
# Got data from tagger
# 200
# Got data from tagger
# 201
# Got data from tagger
# 202
# Got data from tagger
# 203
# Got data from tagger
# 204
# Got data from tagger
# 205
# Got data from tagger
# 206
# Got data from tagger
# 207
# Got data from tagger
# 208
# Got data from tagger
# 209
# Got data from tagger
# 210
# Got data from tagger
# 211
# Got data from tagger
# 212
# Got data from tagger
# 213
# Got data from tagger
# 214
# Got data from tagger
# 215
# Got data from tagger
# 216
# Got data from tagger
# 217
# Got data from tagger
# 218
# Got data from tagger
# 219
# Got data from tagger
# 220
# Got data from tagger
# 221
# Got data from tagger
# 222
# Got data from tagger
# 223
# Got data from tagger
# 224
# Got data from tagger
# 225
# Got data from tagger
# 226
# Got data from tagger
# 227
# Got data from tagger
# 228
# Got data from tagger
# 229
# Got data from tagger
# 230
# Got data from tagger
# 231
# Got data from tagger
# 232
# Got data from tagger
# 233
# Got data from tagger
# 234
# Got data from tagger
# 235
# Got data from tagger
# 236
# Got data from tagger
# 237
# Got data from tagger
# 238
# Got data from tagger
# 239
# Got data from tagger
# 240
# Got data from tagger
# 241
# Got data from tagger
# 242
# Got data from tagger
# 243
# Got data from tagger
# 244
# Got data from tagger
# 245
# Got data from tagger
# 246
# Got data from tagger
# 247
# Got data from tagger
# 248
# Got data from tagger
# 249
# Got data from tagger
# 250
# Got data from tagger
# 251
# Got data from tagger
# 252
# Got data from tagger
# 253
# Got data from tagger
# 254
# Got data from tagger
# 255
# Got data from tagger
# 256
# Got data from tagger
# 257
# Got data from tagger
# 258
# Got data from tagger
# 259
# Got data from tagger
# 260
# Got data from tagger
# 261
# Got data from tagger
# 262
# Got data from tagger
# 263
# Got data from tagger
# 264
# Got data from tagger
# 265
# Got data from tagger
# 266
# Got data from tagger
# 267
# Got data from tagger
# 268
# Got data from tagger
# 269
# Got data from tagger
# 270
# Got data from tagger
# 271
# Got data from tagger
# 272
# Got data from tagger
# 273
# Got data from tagger
# 274
# Got data from tagger
# 275
# Got data from tagger
# 276
# Got data from tagger
# 277
# Got data from tagger
# 278
# Got data from tagger
# 279
# Got data from tagger
# 280
# Got data from tagger
# 281
# Got data from tagger
# 282
# Got data from tagger
# 283
# Got data from tagger
# 284
# Got data from tagger
# 285
# Got data from tagger
# 286
# Got data from tagger
# 287
# Got data from tagger
# 288
# Got data from tagger
# 289
# Got data from tagger
# 290
# Got data from tagger
# 291
# Got data from tagger
# 292
# Got data from tagger
# 293
# Got data from tagger
# 294
# Got data from tagger
# 295
# Got data from tagger
# 296
# Got data from tagger
# 297
# Got data from tagger
# 298
# Got data from tagger
# 299
# Got data from tagger
# 300
# Got data from tagger
# 301
# Got data from tagger
# 302
# Got data from tagger
# 303
# Got data from tagger
# 304
# Got data from tagger
# 305
# Got data from tagger
# 306
# Got data from tagger
# 307
# Got data from tagger
# 308
# Got data from tagger
# 309
# Got data from tagger
# 310
# Got data from tagger
# 311
# Got data from tagger
# 312
# Got data from tagger
# 313
# Got data from tagger
# 314
# Got data from tagger
# 315
# Got data from tagger
# 316
# Got data from tagger
# 317
# Got data from tagger
# 318
# Got data from tagger
# 319
# Got data from tagger
# 320
# Got data from tagger
# 321
# Got data from tagger
# 322
# Got data from tagger
# 323
# Got data from tagger
# 324
# Got data from tagger
# 325
# Got data from tagger
# 326
# Got data from tagger
# 327
# Got data from tagger
# 328
# Got data from tagger
# 329
# Got data from tagger
# 330
# Got data from tagger
# 331
# Got data from tagger
# 332
# Got data from tagger
# 333
# Got data from tagger
# 334
# Got data from tagger
# 335
# Got data from tagger
# 336
# Got data from tagger
# 337
# Got data from tagger
# 338
# Got data from tagger
# 339
# Got data from tagger
# 340
# Got data from tagger
# 341
# Got data from tagger
# 342
# Got data from tagger
# 343
# Got data from tagger
# 344
# Got data from tagger
# 345
# Got data from tagger
# 346
# Got data from tagger
# 347
# Got data from tagger
# 348
# Got data from tagger
# 349
# Got data from tagger
# 350
# Got data from tagger
# 351
# Got data from tagger
# 352
# Got data from tagger
# 353
# Got data from tagger
# 354
# Got data from tagger
# 355
# Got data from tagger
# 356
# Got data from tagger
# 357
# Got data from tagger
# 358
# Got data from tagger
# 359
# Got data from tagger
# 360
# Got data from tagger
# 361
# Got data from tagger
# 362
# Got data from tagger
# 363
# Got data from tagger
# 364
# Got data from tagger
# 365
# Got data from tagger
# 366
# Got data from tagger
# 367
# Got data from tagger
# 368
# Got data from tagger
# 369
# Got data from tagger
# 370
# Got data from tagger
# 371
# Got data from tagger
# 372
# Got data from tagger
# 373
# Got data from tagger
# 374
# Got data from tagger
# 375
# Got data from tagger
# 376
# Got data from tagger
# 377
# Got data from tagger
# 378
# Got data from tagger
# 379
# Got data from tagger
# 380
# Got data from tagger
# 381
# Got data from tagger
# 382
# Got data from tagger
# 383
# Got data from tagger
# 384
# Got data from tagger
# 385
# Got data from tagger
# 386
# Got data from tagger
# 387
# Got data from tagger
# 388
# Got data from tagger
# 389
# Got data from tagger
# 390
# Got data from tagger
# 391
# Got data from tagger
# 392
# Got data from tagger
# 393
# Got data from tagger
# 394
# Got data from tagger
# 395
# Got data from tagger
# 396
# Got data from tagger
# 397
# Got data from tagger
# 398
# Got data from tagger
# 399
# Got data from tagger
# 400
# Got data from tagger
# 401
# Got data from tagger
# 402
# Got data from tagger
# 403
# Got data from tagger
# 404
# Got data from tagger
# 405
# Got data from tagger
# 406
# Got data from tagger
# 407
# Got data from tagger
# 408
# Got data from tagger
# 409
# Got data from tagger
# 410
# Got data from tagger
# 411
# Got data from tagger
# 412
# Got data from tagger
# 413
# Got data from tagger
# 414
# Got data from tagger
# 415
# Got data from tagger
# 416
# Got data from tagger
# 417
# Got data from tagger
# 418
# Got data from tagger
# 419
# Got data from tagger
# 420
# Got data from tagger
# 421
# Got data from tagger
# 422
# Got data from tagger
# 423
# Got data from tagger
# 424
# Got data from tagger
# 425
# Got data from tagger
# 426
# Got data from tagger
# 427
# Got data from tagger
# 428
# Got data from tagger
# 429
# Got data from tagger
# 430
# Got data from tagger
# 431
# Got data from tagger
# 432
# Got data from tagger
# 433
# Got data from tagger
# 434
# Got data from tagger
# 435
# Got data from tagger
# 436
# Got data from tagger
# 437
# Got data from tagger
# 438
# Got data from tagger
# 439
# Got data from tagger
# 440
# Got data from tagger
# 441
# Got data from tagger
# 442
# Got data from tagger
# 443
# Got data from tagger
# 444
# Got data from tagger
# 445
# Got data from tagger
# 446
# Got data from tagger
# 447
# Got data from tagger
# 448
# Got data from tagger
# 449
# Got data from tagger
# 450
# Got data from tagger
# 451
# Got data from tagger
# 452
# Got data from tagger
# 453
# Got data from tagger
# 454
# Got data from tagger
# 455
# Got data from tagger
# 456
# Got data from tagger
# 457
# Got data from tagger
# 458
# Got data from tagger
# 459
# Got data from tagger
# 460
# Got data from tagger
# 461
# Got data from tagger
# 462
# Got data from tagger
# 463
# Got data from tagger
# 464
# Got data from tagger
# 465
# Got data from tagger
# 466
# Got data from tagger
# 467
# Got data from tagger
# 468
# Got data from tagger
# 469
# Got data from tagger
# 470
# Got data from tagger
# 471
# Got data from tagger
# 472
# Got data from tagger
# 473
# Got data from tagger
# 474
# Got data from tagger
# 475
# Got data from tagger
# 476
# Got data from tagger
# 477
# Got data from tagger
# 478
# Got data from tagger
# 479
# Got data from tagger
# 480
# Got data from tagger
# 481
# Got data from tagger
# 482
# Got data from tagger
# 483
# Got data from tagger
# 484
# Got data from tagger
# 485
# Got data from tagger
# 486
# Got data from tagger
# 487
# Got data from tagger
# 488
# Got data from tagger
# 489
# Got data from tagger
# 490
# Got data from tagger
# 491
# Got data from tagger
# 492
# Got data from tagger
# 493
# Got data from tagger
# 494
# Got data from tagger
# 495
# Got data from tagger
# 496
# Got data from tagger
# 497
# Got data from tagger
# 498
# Got data from tagger
# 499
# Got data from tagger
# 500
# Got data from tagger
# 501
# Got data from tagger
# 502
# Got data from tagger
# 503
# Got data from tagger
# 504
# Got data from tagger
# 505
# Got data from tagger
# 506
# Got data from tagger
# 507
# Got data from tagger
# 508
# Got data from tagger
# 509
# Got data from tagger
# 510
# Got data from tagger
# 511
# Got data from tagger
# 512
# Got data from tagger
# 513
# Got data from tagger
# 514
# Got data from tagger
# 515
# Got data from tagger
# 516
# Got data from tagger
# 517
# Got data from tagger
# 518
# Got data from tagger
# 519
# Got data from tagger
# 520
# Got data from tagger
# 521
# Got data from tagger
# 522
# Got data from tagger
# 523
# Got data from tagger
# 524
# Got data from tagger
# 525
# Got data from tagger
# 526
# Got data from tagger
# 527
# Got data from tagger
# 528
# Got data from tagger
# 529
# Got data from tagger
# 530
# Got data from tagger
# 531
# Got data from tagger
# 532
# Got data from tagger
# 533
# Got data from tagger
# 534
# Got data from tagger
# 535
# Got data from tagger
# 536
# Got data from tagger
# 537
# Got data from tagger
# 538
# Got data from tagger
# 539
# Got data from tagger
# 540
# Got data from tagger
# 541
# Got data from tagger
# 542
# Got data from tagger
# 543
# Got data from tagger
# 544
# Got data from tagger
# 545
# Got data from tagger
# 546
# Got data from tagger
# 547
# Got data from tagger
# 548
# Got data from tagger
# 549
# Got data from tagger
# 550
# Got data from tagger
# 551
# Got data from tagger
# 552
# Got data from tagger
# 553
# Got data from tagger
# 554
# Got data from tagger
# 555
# Got data from tagger
# 556
# Got data from tagger
# 557
# Got data from tagger
# 558
# Got data from tagger
# 559
# Got data from tagger
# 560
# Got data from tagger
# 561
# Got data from tagger
# 562
# Got data from tagger
# 563
# Got data from tagger
# 564
# Got data from tagger
# 565
# Got data from tagger
# 566
# Got data from tagger
# 567
# Got data from tagger
# 568
# Got data from tagger
# 569
# Got data from tagger
# 570
# Got data from tagger
# 571
# Got data from tagger
# 572
# Got data from tagger
# 573
# Got data from tagger
# 574
# Got data from tagger
# 575
# Got data from tagger
# 576
# Got data from tagger
# 577
# Got data from tagger
# 578
# Got data from tagger
# 579
# Got data from tagger
# 580
# Got data from tagger
# 581
# Got data from tagger
# 582
# Got data from tagger
# 583
# Got data from tagger
# 584
# Got data from tagger
# 585
# Got data from tagger
# 586
# Got data from tagger
# 587
# Got data from tagger
# 588
# Got data from tagger
# 589
# Got data from tagger
# 590
# Got data from tagger
# 591
# Got data from tagger
# 592
# Got data from tagger
# 593
# Got data from tagger
# 594
# Got data from tagger
# 595
# Got data from tagger
# 596
# Got data from tagger
# 597
# Got data from tagger
# 598
# Got data from tagger
# 599
# Got data from tagger
# 600
# Got data from tagger
# 601
# Got data from tagger
# 602
# Got data from tagger
# 603
# Got data from tagger
# 604
# Got data from tagger
# 605
# Got data from tagger
# 606
# Got data from tagger
# 607
# Got data from tagger
# 608
# Got data from tagger
# 609
# Got data from tagger
# 610
# Got data from tagger
# 611
# Got data from tagger
# 612
# Got data from tagger
# 613
# Got data from tagger
# 614
# Got data from tagger
# 615
# Got data from tagger
# 616
# Got data from tagger
# 617
# Got data from tagger
# 618
# Got data from tagger
# 619
# Got data from tagger
# 620
# Got data from tagger
# 621
# Got data from tagger
# 622
# Got data from tagger
# 623
# Got data from tagger
# 624
# Got data from tagger
# 625
# Got data from tagger
# 626
# Got data from tagger
# 627
# Got data from tagger
# 628
# Got data from tagger
# 629
# Got data from tagger
# 630
# Got data from tagger
# 631
# Got data from tagger
# 632
# Got data from tagger
# 633
# Got data from tagger
# 634
# Got data from tagger
# 635
# Got data from tagger
# 636
# Got data from tagger
# 637
# Got data from tagger
# 638
# Got data from tagger
# 639
# Got data from tagger
# 640
# Got data from tagger
# 641
# Got data from tagger
# 642
# Got data from tagger
# 643
# Got data from tagger
# 644
# Got data from tagger
# 645
# Got data from tagger
# 646
# Got data from tagger
# 647
# Got data from tagger
# 648
# Got data from tagger
# 649
# Got data from tagger
# 650
# Got data from tagger
# 651
# Got data from tagger
# 652
# Got data from tagger
# 653
# Got data from tagger
# 654
# Got data from tagger
# 655
# Got data from tagger
# 656
# Got data from tagger
# 657
# Got data from tagger
# 658
# Got data from tagger
# 659
# Got data from tagger
# 660
# Got data from tagger
# 661
# Got data from tagger
# 662
# Got data from tagger
# 663
# Got data from tagger
# 664
# Got data from tagger
# 665
# Got data from tagger
# 666
# Got data from tagger
# 667
# Got data from tagger
# 668
# Got data from tagger
# 669
# Got data from tagger
# 670
# Got data from tagger
# 671
# Got data from tagger
# 672
# Got data from tagger
# 673
# Got data from tagger
# 674
# Got data from tagger
# 675
# Got data from tagger
# 676
# Got data from tagger
# 677
# Got data from tagger
# 678
# Got data from tagger
# 679
# Got data from tagger
# 680
# Got data from tagger
# 681
# Got data from tagger
# 682
# Got data from tagger
# 683
# Got data from tagger
# 684
# Got data from tagger
# 685
# Got data from tagger
# 686
# Got data from tagger
# 687
# Got data from tagger
# 688
# Got data from tagger
# 689
# Got data from tagger
# 690
# Got data from tagger
# 691
# Got data from tagger
# 692
# Got data from tagger
# 693
# Got data from tagger
# 694
# Got data from tagger
# 695
# Got data from tagger
# 696
# Got data from tagger
# 697
# Got data from tagger
# 698
# Got data from tagger
# 699
# Got data from tagger
# 700
# Got data from tagger
# 701
# Got data from tagger
# 702
# Got data from tagger
# 703
# Got data from tagger
# 704
# Got data from tagger
# 705
# Got data from tagger
# 706
# Got data from tagger
# 707
# Got data from tagger
# 708
# Got data from tagger
# 709
# Got data from tagger
# 710
# Got data from tagger
# 711
# Got data from tagger
# 712
# Got data from tagger
# 713
# Got data from tagger
# 714
# Got data from tagger
# 715
# Got data from tagger
# 716
# Got data from tagger
# 717
# Got data from tagger
# 718
# Got data from tagger
# 719
# Got data from tagger
# 720
# Got data from tagger
# 721
# Got data from tagger
# 722
# Got data from tagger
# 723
# Got data from tagger
# 724
# Got data from tagger
# 725
# Got data from tagger
# 726
# Got data from tagger
# 727
# Got data from tagger
# 728
# Got data from tagger
# 729
# Got data from tagger
# 730
# Got data from tagger
# 731
# Got data from tagger
# 732
# Got data from tagger
# 733
# Got data from tagger
# 734
# Got data from tagger
# 735
# Got data from tagger
# 736
# Got data from tagger
# 737
# Got data from tagger
# 738
# Got data from tagger
# 739
# Got data from tagger
# 740
# Got data from tagger
# 741
# Got data from tagger
# 742
# Got data from tagger
# 743
# Got data from tagger
# 744
# Got data from tagger
# 745
# Got data from tagger
# 746
# Got data from tagger
# 747
# Got data from tagger
# 748
# Got data from tagger
# 749
# Got data from tagger
# 750
# Got data from tagger
# 751
# Got data from tagger
# 752
# Got data from tagger
# 753
# Got data from tagger
# 754
# Got data from tagger
# 755
# Got data from tagger
# 756
# Got data from tagger
# 757
# Got data from tagger
# 758
# Got data from tagger
# 759
# Got data from tagger
# 760
# Got data from tagger
# 761
# Got data from tagger
# 762
# Got data from tagger
# 763
# Got data from tagger
# 764
# Got data from tagger
# 765
# Got data from tagger
# 766
# Got data from tagger
# 767
# Got data from tagger
# 768
# Got data from tagger
# 769
# Got data from tagger
# 770
# Got data from tagger
# 771
# Got data from tagger
# 772
# Got data from tagger
# 773
# Got data from tagger
# 774
# Got data from tagger
# 775
# Got data from tagger
# 776
# Got data from tagger
# 777
# Got data from tagger
# 778
# Got data from tagger
# 779
# Got data from tagger
# 780
# Got data from tagger
# 781
# Got data from tagger
# 782
# Got data from tagger
# 783
# Got data from tagger
# 784
# Got data from tagger
# 785
# Got data from tagger
# 786
# Got data from tagger
# 787
# Got data from tagger
# 788
# Got data from tagger
# 789
# Got data from tagger
# 790
# Got data from tagger
# 791
# Got data from tagger
# 792
# Got data from tagger
# 793
# Got data from tagger
# 794
# Got data from tagger
# 795
# Got data from tagger
# 796
# Got data from tagger
# 797
# Got data from tagger
# 798
# Got data from tagger
# 799
# Got data from tagger
# 800
# Got data from tagger
# 801
# Got data from tagger
# 802
# Got data from tagger
# 803
# Got data from tagger
# 804
# Got data from tagger
# 805
# Got data from tagger
# 806
# Got data from tagger
# 807
# Got data from tagger
# 808
# Got data from tagger
# 809
# Got data from tagger
# 810
# Got data from tagger
# 811
# Got data from tagger
# 812
# Got data from tagger
# 813
# Got data from tagger
# 814
# Got data from tagger
# 815
# Got data from tagger
# 816
# Got data from tagger
# 817
# Got data from tagger
# 818
# Got data from tagger
# 819
# Got data from tagger
# 820
# Got data from tagger
# 821
# Got data from tagger
# 822
# Got data from tagger
# 823
# Got data from tagger
# 824
# Got data from tagger
# 825
# Got data from tagger
# 826
# Got data from tagger
# 827
# Got data from tagger
# 828
# Got data from tagger
# 829
# Got data from tagger
# 830
# Got data from tagger
# 831
# Got data from tagger
# 832
# Got data from tagger
# 833
# Got data from tagger
# 834
# Got data from tagger
# 835
# Got data from tagger
# 836
# Got data from tagger
# 837
# Got data from tagger
# 838
# Got data from tagger
# 839
# Got data from tagger
# 840
# Got data from tagger
# 841
# Got data from tagger
# 842
# Got data from tagger
# 843
# Got data from tagger
# 844
# Got data from tagger
# 845
# Got data from tagger
# 846
# Got data from tagger
# 847
# Got data from tagger
# 848
# Got data from tagger
# 849
# Got data from tagger
# 850
# Got data from tagger
# 851
# Got data from tagger
# 852
# Got data from tagger
# 853
# Got data from tagger
# 854
# Got data from tagger
# 855
# Got data from tagger
# 856
# Got data from tagger
# 857
# Got data from tagger
# 858
# Got data from tagger
# 859
# Got data from tagger
# 860
# Got data from tagger
# 861
# Got data from tagger
# 862
# Got data from tagger
# 863
# Got data from tagger
# 864
# Got data from tagger
# 865
# Got data from tagger
# 866
# Got data from tagger
# 867
# Got data from tagger
# 868
# Got data from tagger
# 869
# Got data from tagger
# 870
# Got data from tagger
# 871
# Got data from tagger
# 872
# Got data from tagger
# 873
# Got data from tagger
# 874
# Got data from tagger
# 875
# Got data from tagger
# 876
# Got data from tagger
# 877
# Got data from tagger
# 878
# Got data from tagger
# 879
# Got data from tagger
# 880
# Got data from tagger
# 881
# Got data from tagger
# 882
# Got data from tagger
# 883
# Got data from tagger
# 884
# Got data from tagger
# 885
# Got data from tagger
# 886
# Got data from tagger
# 887
# Got data from tagger
# 888
# Got data from tagger
# 889
# Got data from tagger
# 890
# Got data from tagger
# 891
# Got data from tagger
# 892
# Got data from tagger
# 893
# Got data from tagger
# 894
# Got data from tagger
# 895
# Got data from tagger
# 896
# Got data from tagger
# 897
# Got data from tagger
# 898
# Got data from tagger
# 899
# Got data from tagger
# 900
# Got data from tagger
# 901
# Got data from tagger
# 902
# Got data from tagger
# 903
# Got data from tagger
# 904
# Got data from tagger
# 905
# Got data from tagger
# 906
# Got data from tagger
# 907
# Got data from tagger
# 908
# Got data from tagger
# 909
# Got data from tagger
# 910
# Got data from tagger
# 911
# Got data from tagger
# 912
# Got data from tagger
# 913
# Got data from tagger
# 914
# Got data from tagger
# 915
# Got data from tagger
# 916
# Got data from tagger
# 917
# Got data from tagger
# 918
# Got data from tagger
# 919
# Got data from tagger
# 920
# Got data from tagger
# 921
# Got data from tagger
# 922
# Got data from tagger
# 923
# Got data from tagger
# 924
# Got data from tagger
# 925
# Got data from tagger
# 926
# Got data from tagger
# 927
# Got data from tagger
# 928
# Got data from tagger
# 929
# Got data from tagger
# 930
# Got data from tagger
# 931
# Got data from tagger
# 932
# Got data from tagger
# 933
# Got data from tagger
# 934
# Got data from tagger
# 935
# Got data from tagger
# 936
# Got data from tagger
# 937
# Got data from tagger
# 938
# Got data from tagger
# 939
# Got data from tagger
# 940
# Got data from tagger
# 941
# Got data from tagger
# 942
# Got data from tagger
# 943
# Got data from tagger
# 944
# Got data from tagger
# 945
# Got data from tagger
# 946
# Got data from tagger
# 947
# Got data from tagger
# 948
# Got data from tagger
# 949
# Got data from tagger
# 950
# Got data from tagger
# 951
# Got data from tagger
# 952
# Got data from tagger
# 953
# Got data from tagger
# 954
# Got data from tagger
# 955
# Got data from tagger
# 956
# Got data from tagger
# 957
# Got data from tagger
# 958
# Got data from tagger
# 959
# Got data from tagger
# 960
# Got data from tagger
# 961
# Got data from tagger
# 962
# Got data from tagger
# 963
# Got data from tagger
# 964
# Got data from tagger
# 965
# Got data from tagger
# 966
# Got data from tagger
# 967
# Got data from tagger
# 968
# Got data from tagger
# 969
# Got data from tagger
# 970
# Got data from tagger
# 971
# Got data from tagger
# 972
# Got data from tagger
# 973
# Got data from tagger
# 974
# Got data from tagger
# 975
# Got data from tagger
# 976
# Got data from tagger
# 977
# Got data from tagger
# 978
# Got data from tagger
# 979
# Got data from tagger
# 980
# Got data from tagger
# 981
# Got data from tagger
# 982
# Got data from tagger
# 983
# Got data from tagger
# 984
# Got data from tagger
# 985
# Got data from tagger
# 986
# Got data from tagger
# 987
# Got data from tagger
# 988
# Got data from tagger
# 989
# Got data from tagger
# 990
# Got data from tagger
# 991
# Got data from tagger
# 992
# Got data from tagger
# 993
# Got data from tagger
# 994
# Got data from tagger
# 995
# Got data from tagger
# 996
# Got data from tagger
# 997
# Got data from tagger
# 998
# Got data from tagger
# 999
# Got data from tagger
# 1000
# Got data from tagger
# 1001
# Got data from tagger
# 1002
# Got data from tagger
# 1003
# Got data from tagger
# 1004
# Got data from tagger
# 1005
# Got data from tagger
# 1006
# Got data from tagger
# 1007
# Got data from tagger
# 1008
# Got data from tagger
# 1009
# Got data from tagger
# 1010
# Got data from tagger
# 1011
# Got data from tagger
# 1012
# Got data from tagger
# 1013
# Got data from tagger
# 1014
# Got data from tagger
# 1015
# Got data from tagger
# 1016
# Got data from tagger
# 1017
# Got data from tagger
# 1018
# Got data from tagger
# 1019
# Got data from tagger
# 1020
# Got data from tagger
# 1021
# Got data from tagger
# 1022
# Got data from tagger
# 1023
# Got data from tagger
# 1024
# Got data from tagger
# 1025
# Got data from tagger
# 1026
# Got data from tagger
# 1027
# Got data from tagger
# 1028
# Got data from tagger
# 1029
# Got data from tagger
# 1030
# Got data from tagger
# 1031
# Got data from tagger
# 1032
# Got data from tagger
# 1033
# Got data from tagger
# 1034
# Got data from tagger
# 1035
# Got data from tagger
# 1036
# Got data from tagger
# 1037
# Got data from tagger
# 1038
# Got data from tagger
# 1039
# Got data from tagger
# 1040
# Got data from tagger
# 1041
# Got data from tagger
# 1042
# Got data from tagger
# 1043
# Got data from tagger
# 1044
# Got data from tagger
# 1045
# Got data from tagger
# 1046
# Got data from tagger
# 1047
# Got data from tagger
# 1048
# Got data from tagger
# 1049
# Got data from tagger
# 1050
# Got data from tagger
# 1051
# Got data from tagger
# 1052
# Got data from tagger
# 1053
# Got data from tagger
# 1054
# Got data from tagger
# 1055
# Got data from tagger
# 1056
# Got data from tagger
# 1057
# Got data from tagger
# 1058
# Got data from tagger
# 1059
# Got data from tagger
# 1060
# Got data from tagger
# 1061
# Got data from tagger
# 1062
# Got data from tagger
# 1063
# Got data from tagger
# 1064
# Got data from tagger
# 1065
# Got data from tagger
# 1066
# Got data from tagger
# 1067
# Got data from tagger
# 1068
# Got data from tagger
# 1069
# Got data from tagger
# 1070
# Got data from tagger
# 1071
# Got data from tagger
# 1072
# Got data from tagger
# 1073
# Got data from tagger
# 1074
# Got data from tagger
# 1075
# Got data from tagger
# 1076
# Got data from tagger
# 1077
# Got data from tagger
# 1078
# Got data from tagger
# 1079
# Got data from tagger
# 1080
# Got data from tagger
# 1081
# Got data from tagger
# 1082
# Got data from tagger
# 1083
# Got data from tagger
# 1084
# Got data from tagger
# 1085
# Got data from tagger
# 1086
# Got data from tagger
# 1087
# Got data from tagger
# 1088
# Got data from tagger
# 1089
# Got data from tagger
# 1090
# Got data from tagger
# 1091
# Got data from tagger
# 1092
# Got data from tagger
# 1093
# Got data from tagger
# 1094
# Got data from tagger
# 1095
# Got data from tagger
# 1096
# Got data from tagger
# 1097
# Got data from tagger
# 1098
# Got data from tagger
# 1099
# Got data from tagger
# 1100
# Got data from tagger
# 1101
# Got data from tagger
# 1102
# Got data from tagger
# 1103
# Got data from tagger
# 1104
# Got data from tagger
# 1105
# Got data from tagger
# 1106
# Got data from tagger
# 1107
# Got data from tagger
# 1108
# Got data from tagger
# 1109
# Got data from tagger
# 1110
# Got data from tagger
# 1111
# Got data from tagger
# 1112
# Got data from tagger
# 1113
# Got data from tagger
# 1114
# Got data from tagger
# 1115
# Got data from tagger
# 1116
# Got data from tagger
# 1117
# Got data from tagger
# 1118
# Got data from tagger
# 1119
# Got data from tagger
# 1120
# Got data from tagger
# 1121
# Got data from tagger
# 1122
# Got data from tagger
# 1123
# Got data from tagger
# 1124
# Got data from tagger
# 1125
# Got data from tagger
# 1126
# Got data from tagger
# 1127
# Got data from tagger
# 1128
# Got data from tagger
# 1129
# Got data from tagger
# 1130
# Got data from tagger
# 1131
# Got data from tagger
# 1132
# Got data from tagger
# 1133
# Got data from tagger
# 1134
# Got data from tagger
# 1135
# Got data from tagger
# 1136
# Got data from tagger
# 1137
# Got data from tagger
# 1138
# Got data from tagger
# 1139
# Got data from tagger
# 1140
# Got data from tagger
# 1141
# Got data from tagger
# 1142
# Got data from tagger
# 1143
# Got data from tagger
# 1144
# Got data from tagger
# 1145
# Got data from tagger
# 1146
# Got data from tagger
# 1147
# Got data from tagger
# 1148
# Got data from tagger
# 1149
# Got data from tagger
# 1150
# Got data from tagger
# 1151
# Got data from tagger
# 1152
# Got data from tagger
# 1153
# Got data from tagger
# 1154
# Got data from tagger
# 1155
# Got data from tagger
# 1156
# Got data from tagger
# 1157
# Got data from tagger
# 1158
# Got data from tagger
# 1159
# Got data from tagger
# 1160
# Got data from tagger
# 1161
# Got data from tagger
# 1162
# Got data from tagger
# 1163
# Got data from tagger
# 1164
# Got data from tagger
# 1165
# Got data from tagger
# 1166
# Got data from tagger
# 1167
# Got data from tagger
# 1168
# Got data from tagger
# 1169
# Got data from tagger
# 1170
# Got data from tagger
# 1171
# Got data from tagger
# 1172
# Got data from tagger
# 1173
# Got data from tagger
# 1174
# Got data from tagger
# 1175
# Got data from tagger
# 1176
# Got data from tagger
# 1177
# Got data from tagger
# 1178
# Got data from tagger
# 1179
# Got data from tagger
# 1180
# Got data from tagger
# 1181
# Got data from tagger
# 1182
# Got data from tagger
# 1183
# Got data from tagger
# 1184
# Got data from tagger
# 1185
# Got data from tagger
# 1186
# Got data from tagger
# 1187
# Got data from tagger
# 1188
# Got data from tagger
# 1189
# Got data from tagger
# 1190
# Got data from tagger
# 1191
# Got data from tagger
# 1192
# Got data from tagger
# 1193
# Got data from tagger
# 1194
# Got data from tagger
# 1195
# Got data from tagger
# 1196
# Got data from tagger
# 1197
# Got data from tagger
# 1198
# Got data from tagger
# 1199
# Got data from tagger
# 1200
# Got data from tagger
# 1201
# Got data from tagger
# 1202
# Got data from tagger
# 1203
# Got data from tagger
# 1204
# Got data from tagger
# 1205
# Got data from tagger
# 1206
# Got data from tagger
# 1207
# Got data from tagger
# 1208
# Got data from tagger
# 1209
# Got data from tagger
# 1210
# Got data from tagger
# 1211
# Got data from tagger
# 1212
# Got data from tagger
# 1213
# Got data from tagger
# 1214
# Got data from tagger
# 1215
# Got data from tagger
# 1216
# Got data from tagger
# 1217
# Got data from tagger
# 1218
# Got data from tagger
# 1219
# Got data from tagger
# 1220
# Got data from tagger
# 1221
# Got data from tagger
# 1222
# Got data from tagger
# 1223
# Got data from tagger
# 1224
# Got data from tagger
# 1225
# Got data from tagger
# 1226
# Got data from tagger
# 1227
# Got data from tagger
# 1228
# Got data from tagger
# 1229
# Got data from tagger
# 1230
# Got data from tagger
# 1231
# Got data from tagger
# 1232
# Got data from tagger
# 1233
# Got data from tagger
# 1234
# Got data from tagger
# 1235
# Got data from tagger
# 1236
# Got data from tagger
# 1237
# Got data from tagger
# 1238
# Got data from tagger
# 1239
# Got data from tagger
# 1240
# Got data from tagger
# 1241
# Got data from tagger
# 1242
# Got data from tagger
# 1243
# Got data from tagger
# 1244
# Got data from tagger
# 1245
# Got data from tagger
# 1246
# Got data from tagger
# 1247
# Got data from tagger
# 1248
# Got data from tagger
# 1249
# Got data from tagger
# 1250
# Got data from tagger
# 1251
# Got data from tagger
# 1252
# Got data from tagger
# 1253
# Got data from tagger
# 1254
# Got data from tagger
# 1255
# Got data from tagger
# 1256
# Got data from tagger
# 1257
# Got data from tagger
# 1258
# Got data from tagger
# 1259
# Got data from tagger
# 1260
# Got data from tagger
# 1261
# Got data from tagger
# 1262
# Got data from tagger
# 1263
# Got data from tagger
# 1264
# Got data from tagger
# 1265
# Got data from tagger
# 1266
# Got data from tagger
# 1267
# Got data from tagger
# 1268
# Got data from tagger
# 1269
# Got data from tagger
# 1270
# Got data from tagger
# 1271
# Got data from tagger
# 1272
# Got data from tagger
# 1273
# Got data from tagger
# 1274
# Got data from tagger
# 1275
# Got data from tagger
# 1276
# Got data from tagger
# 1277
# Got data from tagger
# 1278
# Got data from tagger
# 1279
# Got data from tagger
# 1280
# Got data from tagger
# 1281
# Got data from tagger
# 1282
# Got data from tagger
# 1283
# Got data from tagger
# 1284
# Got data from tagger
# 1285
# Got data from tagger
# 1286
# Got data from tagger
# 1287
# Got data from tagger
# 1288
# Got data from tagger
# 1289
# Got data from tagger
# 1290
# Got data from tagger
# 1291
# Got data from tagger
# 1292
# Got data from tagger
# 1293
# Got data from tagger
# 1294
# Got data from tagger
# 1295
# Got data from tagger
# 1296
# Got data from tagger
# 1297
# Got data from tagger
# 1298
# Got data from tagger
# 1299
# Got data from tagger
# 1300
# Got data from tagger
# 1301
# Got data from tagger
# 1302
# Got data from tagger
# 1303
# Got data from tagger
# 1304
# Got data from tagger
# 1305
# Got data from tagger
# 1306
# Got data from tagger
# 1307
# Got data from tagger
# 1308
# Got data from tagger
# 1309
# Got data from tagger
# 1310
# Got data from tagger
# 1311
# Got data from tagger
# 1312
# Got data from tagger
# 1313
# Got data from tagger
# 1314
# Got data from tagger
# 1315
# Got data from tagger
# 1316
# Got data from tagger
# 1317
# Got data from tagger
# 1318
# Got data from tagger
# 1319
# Got data from tagger
# 1320
# Got data from tagger
# 1321
# Got data from tagger
# 1322
# Got data from tagger
# 1323
# Got data from tagger
# 1324
# Got data from tagger
# 1325
# Got data from tagger
# 1326
# Got data from tagger
# 1327
# Got data from tagger
# 1328
# Got data from tagger
# 1329
# Got data from tagger
# 1330
# Got data from tagger
# 1331
# Got data from tagger
# 1332
# Got data from tagger
# 1333
# Got data from tagger
# 1334
# Got data from tagger
# 1335
# Got data from tagger
# 1336
# Got data from tagger
# 1337
# Got data from tagger
# 1338
# Got data from tagger
# 1339
# Got data from tagger
# 1340
# Got data from tagger
# 1341
# Got data from tagger
# 1342
# Got data from tagger
# 1343
# Got data from tagger
# 1344
# Got data from tagger
# 1345
# Got data from tagger
# 1346
# Got data from tagger
# 1347
# Got data from tagger
# 1348
# Got data from tagger
# 1349
# Got data from tagger
# 1350
# Got data from tagger
# 1351
# Got data from tagger
# 1352
# Got data from tagger
# 1353
# Got data from tagger
# 1354
# Got data from tagger
# 1355
# Got data from tagger
# 1356
# Got data from tagger
# 1357
# Got data from tagger
# 1358
# Got data from tagger
# 1359
# Got data from tagger
# 1360
# Got data from tagger
# 1361
# Got data from tagger
# 1362
# Got data from tagger
# 1363
# Got data from tagger
# 1364
# Got data from tagger
# 1365
# Got data from tagger
# 1366
# Got data from tagger
# 1367
# Got data from tagger
# 1368
# Got data from tagger
# 1369
# Got data from tagger
# 1370
# Got data from tagger
# 1371
# Got data from tagger
# 1372
# Got data from tagger
# 1373
# Got data from tagger
# 1374
# Got data from tagger
# 1375
# Got data from tagger
# 1376
# Got data from tagger
# 1377
# Got data from tagger
# 1378
# Got data from tagger
# 1379
# Got data from tagger
# 1380
# Got data from tagger
# 1381
# Got data from tagger
# 1382
# Got data from tagger
# 1383
# Got data from tagger
# 1384
# Got data from tagger
# 1385
# Got data from tagger
# 1386
# Got data from tagger
# 1387
# Got data from tagger
# 1388
# Got data from tagger
# 1389
# Got data from tagger
# 1390
# Got data from tagger
# 1391
# Got data from tagger
# 1392
# Got data from tagger
# 1393
# Got data from tagger
# 1394
# Got data from tagger
# 1395
# Got data from tagger
# 1396
# Got data from tagger
# 1397
# Got data from tagger
# 1398
# Got data from tagger
# 1399
# Got data from tagger
# 1400
# Got data from tagger
# 1401
# Got data from tagger
# 1402
# Got data from tagger
# 1403
# Got data from tagger
# 1404
# Got data from tagger
# 1405
# Got data from tagger
# 1406
# Got data from tagger
# 1407
# Got data from tagger
# 1408
# Got data from tagger
# 1409
# Got data from tagger
# 1410
# Got data from tagger
# 1411
# Got data from tagger
# 1412
# Got data from tagger
# 1413
# Got data from tagger
# 1414
# Got data from tagger
# 1415
# Got data from tagger
# 1416
# Got data from tagger
# 1417
# Got data from tagger
# 1418
# Got data from tagger
# 1419
# Got data from tagger
# 1420
# Got data from tagger
# 1421
# Got data from tagger
# 1422
# Got data from tagger
# 1423
# Got data from tagger
# 1424
# Got data from tagger
# 1425
# Got data from tagger
# 1426
# Got data from tagger
# 1427
# Got data from tagger
# 1428
# Got data from tagger
# 1429
# Got data from tagger
# 1430
# Got data from tagger
# 1431
# Got data from tagger
# 1432
# Got data from tagger
# 1433
# Got data from tagger
# 1434
# Got data from tagger
# 1435
# Got data from tagger
# 1436
# Got data from tagger
# 1437
# Got data from tagger
# 1438
# Got data from tagger
# 1439
# Got data from tagger
# 1440
# Got data from tagger
# 1441
# Got data from tagger
# 1442
# Got data from tagger
# 1443
# Got data from tagger
# 1444
# Got data from tagger
# 1445
# Got data from tagger
# 1446
# Got data from tagger
# 1447
# Got data from tagger
# 1448
# Got data from tagger
# 1449
# Got data from tagger
# 1450
# Got data from tagger
# 1451
# Got data from tagger
# 1452
# Got data from tagger
# 1453
# Got data from tagger
# 1454
# Got data from tagger
# 1455
# Got data from tagger
# 1456
# Got data from tagger
# 1457
# Got data from tagger
# 1458
# Got data from tagger
# 1459
# Got data from tagger
# 1460
# Got data from tagger
# 1461
# Got data from tagger
# 1462
# Got data from tagger
# 1463
# Got data from tagger
# 1464
# Got data from tagger
# 1465
# Got data from tagger
# 1466
# Got data from tagger
# 1467
# Got data from tagger
# 1468
# Got data from tagger
# 1469
# Got data from tagger
# 1470
# Got data from tagger
# 1471
# Got data from tagger
# 1472
# Got data from tagger
# 1473
# Got data from tagger
# 1474
# Got data from tagger
# 1475
# Got data from tagger
# 1476
# Got data from tagger
# 1477
# Got data from tagger
# 1478
# Got data from tagger
# 1479
# Got data from tagger
# 1480
# Got data from tagger
# 1481
# Got data from tagger
# 1482
# Got data from tagger
# 1483
# Got data from tagger
# 1484
# Got data from tagger
# 1485
# Got data from tagger
# 1486
# Got data from tagger
# 1487
# Got data from tagger
# 1488
# Got data from tagger
# 1489
# Got data from tagger
# 1490
# Got data from tagger
# 1491
# Got data from tagger
# 1492
# Got data from tagger
# 1493
# Got data from tagger
# 1494
# Got data from tagger
# 1495
# Got data from tagger
# 1496
# Got data from tagger
# 1497
# Got data from tagger
# 1498
# Got data from tagger
# 1499
# Got data from tagger
# 1500
# Got data from tagger
# 1501
# Got data from tagger
# 1502
# Got data from tagger
# 1503
# Got data from tagger
# 1504
# Got data from tagger
# 1505
# Got data from tagger
# 1506
# Got data from tagger
# 1507
# Got data from tagger
# 1508
# Got data from tagger
# 1509
# Got data from tagger
# 1510
# Got data from tagger
# 1511
# Got data from tagger
# 1512
# Got data from tagger
# 1513
# Got data from tagger
# 1514
# Got data from tagger
# 1515
# Got data from tagger
# 1516
# Got data from tagger
# 1517
# Got data from tagger
# 1518
# Got data from tagger
# 1519
# Got data from tagger
# 1520
# Got data from tagger
# 1521
# Got data from tagger
# 1522
# Got data from tagger
# 1523
# Got data from tagger
# 1524
# Got data from tagger
# 1525
# Got data from tagger
# 1526
# Got data from tagger
# 1527
# Got data from tagger
# 1528
# Got data from tagger
# 1529
# Got data from tagger
# 1530
# Got data from tagger
# 1531
# Got data from tagger
# 1532
# Got data from tagger
# 1533
# Got data from tagger
# 1534
# Got data from tagger
# 1535
# Got data from tagger
# 1536
# Got data from tagger
# 1537
# Got data from tagger
# 1538
# Got data from tagger
# 1539
# Got data from tagger
# 1540
# Got data from tagger
# 1541
# Got data from tagger
# 1542
# Got data from tagger
# 1543
# Got data from tagger
# 1544
# Got data from tagger
# 1545
# Got data from tagger
# 1546
# Got data from tagger
# 1547
# Got data from tagger
# 1548
# Got data from tagger
# 1549
# Got data from tagger
# 1550
# Got data from tagger
# 1551
# Got data from tagger
# 1552
# Got data from tagger
# 1553
# Got data from tagger
# 1554
# Got data from tagger
# 1555
# Got data from tagger
# 1556
# Got data from tagger
# 1557
# Got data from tagger
# 1558
# Got data from tagger
# 1559
# Got data from tagger
# 1560
# Got data from tagger
# 1561
# Got data from tagger
# 1562
# Got data from tagger
# 1563
# Got data from tagger
# 1564
# Got data from tagger
# 1565
# Got data from tagger
# 1566
# Got data from tagger
# 1567
# Got data from tagger
# 1568
# Got data from tagger
# 1569
# Got data from tagger
# 1570
# Got data from tagger
# 1571
# Got data from tagger
# 1572
# Got data from tagger
# 1573
# Got data from tagger
# 1574
# Got data from tagger
# 1575
# Got data from tagger
# 1576
# Got data from tagger
# 1577
# Got data from tagger
# 1578
# Got data from tagger
# 1579
# Got data from tagger
# 1580
# Got data from tagger
# 1581
# Got data from tagger
# 1582
# Got data from tagger
# 1583
# Got data from tagger
# 1584
# Got data from tagger
# 1585
# Got data from tagger
# 1586
# Got data from tagger
# 1587
# Got data from tagger
# 1588
# Got data from tagger
# 1589
# Got data from tagger
# 1590
# Got data from tagger
# 1591
# Got data from tagger
# 1592
# Got data from tagger
# 1593
# Got data from tagger
# 1594
# Got data from tagger
# 1595
# Got data from tagger
# 1596
# Got data from tagger
# 1597
# Got data from tagger
# 1598
# Got data from tagger
# 1599
# Got data from tagger
# 1600
# Got data from tagger
# 1601
# Got data from tagger
# 1602
# Got data from tagger
# 1603
# Got data from tagger
# 1604
# Got data from tagger
# 1605
# Got data from tagger
# 1606
# Got data from tagger
# 1607
# Got data from tagger
# 1608
# Got data from tagger
# 1609
# Got data from tagger
# 1610
# Got data from tagger
# 1611
# Got data from tagger
# 1612
# Got data from tagger
# 1613
# Got data from tagger
# 1614
# Got data from tagger
# 1615
# Got data from tagger
# 1616
# Got data from tagger
# 1617
# Got data from tagger
# 1618
# Got data from tagger
# 1619
# Got data from tagger
# 1620
# Got data from tagger
# 1621
# Got data from tagger
# 1622
# Got data from tagger
# 1623
# Got data from tagger
# 1624
# Got data from tagger
# 1625
# Got data from tagger
# 1626
# Got data from tagger
# 1627
# Got data from tagger
# 1628
# Got data from tagger
# 1629
# Got data from tagger
# 1630
# Got data from tagger
# 1631
# Got data from tagger
# 1632
# Got data from tagger
# 1633
# Got data from tagger
# 1634
# Got data from tagger
# 1635
# Got data from tagger
# 1636
# Got data from tagger
# 1637
# Got data from tagger
# 1638
# Got data from tagger
# 1639
# Got data from tagger
# 1640
# Got data from tagger
# 1641
# Got data from tagger
# 1642
# Got data from tagger
# 1643
# Got data from tagger
# 1644
# Got data from tagger
# 1645
# Got data from tagger
# 1646
# Got data from tagger
# 1647
# Got data from tagger
# 1648
# Got data from tagger
# 1649
# Got data from tagger
# 1650
# Got data from tagger
# 1651
# Got data from tagger
# 1652
# Got data from tagger
# 1653
# Got data from tagger
# 1654
# Got data from tagger
# 1655
# Got data from tagger
# 1656
# Got data from tagger
# 1657
# Got data from tagger
# 1658
# Got data from tagger
# 1659
# Got data from tagger
# 1660
# Got data from tagger
# 1661
# Got data from tagger
# 1662
# Got data from tagger
# 1663
# Got data from tagger
# 1664
# Got data from tagger
# 1665
# Got data from tagger
# 1666
# Got data from tagger
# 1667
# Got data from tagger
# 1668
# Got data from tagger
# 1669
# Got data from tagger
# 1670
# Got data from tagger
# 1671
# Got data from tagger
# 1672
# Got data from tagger
# 1673
# Got data from tagger
# 1674
# Got data from tagger
# 1675
# Got data from tagger
# 1676
# Got data from tagger
# 1677
# Got data from tagger
# 1678
# Got data from tagger
# 1679
# Got data from tagger
# 1680
# Got data from tagger
# 1681
# Got data from tagger
# 1682
# Got data from tagger
# 1683
# Got data from tagger
# 1684
# Got data from tagger
# 1685
# Got data from tagger
# 1686
# Got data from tagger
# 1687
# Got data from tagger
# 1688
# Got data from tagger
# 1689
# Got data from tagger
# 1690
# Got data from tagger
# 1691
# Got data from tagger
# 1692
# Got data from tagger
# 1693
# Got data from tagger
# 1694
# Got data from tagger
# 1695
# Got data from tagger
# 1696
# Got data from tagger
# 1697
# Got data from tagger
# 1698
# Got data from tagger
# 1699
# Got data from tagger
# 1700
# Got data from tagger
# 1701
# Got data from tagger
# 1702
# Got data from tagger
# 1703
# Got data from tagger
# 1704
# Got data from tagger
# 1705
# Got data from tagger
# 1706
# Got data from tagger
# 1707
# Got data from tagger
# 1708
# Got data from tagger
# 1709
# Got data from tagger
# 1710
# Got data from tagger
# 1711
# Got data from tagger
# 1712
# Got data from tagger
# 1713
# Got data from tagger
# 1714
# Got data from tagger
# 1715
# Got data from tagger
# 1716
# Got data from tagger
# 1717
# Got data from tagger
# 1718
# Got data from tagger
# 1719
# Got data from tagger
# 1720
# Got data from tagger
# 1721
# Got data from tagger
# 1722
# Got data from tagger
# 1723
# Got data from tagger
# 1724
# Got data from tagger
# 1725
# Got data from tagger
# 1726
# Got data from tagger
# 1727
# Got data from tagger
# 1728
# Got data from tagger
# 1729
# Got data from tagger
# 1730
# Got data from tagger
# 1731
# Got data from tagger
# 1732
# Got data from tagger
# 1733
# Got data from tagger
# 1734
# Got data from tagger
# 1735
# Got data from tagger
# 1736
# Got data from tagger
# 1737
# Got data from tagger
# 1738
# Got data from tagger
# 1739
# Got data from tagger
# 1740
# Got data from tagger
# 1741
# Got data from tagger
# 1742
# Got data from tagger
# 1743
# Got data from tagger
# 1744
# Got data from tagger
# 1745
# Got data from tagger
# 1746
# Got data from tagger
# 1747
# Got data from tagger
# 1748
# Got data from tagger
# 1749
# Got data from tagger
# 1750
# Got data from tagger
# 1751
# Got data from tagger
# 1752
# Got data from tagger
# 1753
# Got data from tagger
# 1754
# Got data from tagger
# 1755
# Got data from tagger
# 1756
# Got data from tagger
# 1757
# Got data from tagger
# 1758
# Got data from tagger
# 1759
# Got data from tagger
# 1760
# Got data from tagger
# 1761
# Got data from tagger
# 1762
# Got data from tagger
# 1763
# Got data from tagger
# 1764
# Got data from tagger
# 1765
# Got data from tagger
# 1766
# Got data from tagger
# 1767
# Got data from tagger
# 1768
# Got data from tagger
# 1769
# Got data from tagger
# 1770
# Got data from tagger
# 1771
# Got data from tagger
# 1772
# Got data from tagger
# 1773
# Got data from tagger
# 1774
# Got data from tagger
# 1775
# Got data from tagger
# 1776
# Got data from tagger
# 1777
# Got data from tagger
# 1778
# Got data from tagger
# 1779
# Got data from tagger
# 1780
# Got data from tagger
# 1781
# Got data from tagger
# 1782
# Got data from tagger
# 1783
# Got data from tagger
# 1784
# Got data from tagger
# 1785
# Got data from tagger
# 1786
# Got data from tagger
# 1787
# Got data from tagger
# 1788
# Got data from tagger
# 1789
# Got data from tagger
# 1790
# Got data from tagger
# 1791
# Got data from tagger
# 1792
# Got data from tagger
# 1793
# Got data from tagger
# 1794
# Got data from tagger
# 1795
# Got data from tagger
# 1796
# Got data from tagger
# 1797
# Got data from tagger
# 1798
# Got data from tagger
# 1799
# Got data from tagger
# 1800
# Got data from tagger
# 1801
# Got data from tagger
# 1802
# Got data from tagger
# 1803
# Got data from tagger
# 1804
# Got data from tagger
# 1805
# Got data from tagger
# 1806
# Got data from tagger
# 1807
# Got data from tagger
# 1808
# Got data from tagger
# 1809
# Got data from tagger
# 1810
# Got data from tagger
# 1811
# Got data from tagger
# 1812
# Got data from tagger
# 1813
# Got data from tagger
# 1814
# Got data from tagger
# 1815
# Got data from tagger
# 1816
# Got data from tagger
# 1817
# Got data from tagger
# 1818
# Got data from tagger
# 1819
# Got data from tagger
# 1820
# Got data from tagger
# 1821
# Got data from tagger
# 1822
# Got data from tagger
# 1823
# Got data from tagger
# 1824
# Got data from tagger
# 1825
# Got data from tagger
# 1826
# Got data from tagger
# 1827
# Got data from tagger
# 1828
# Got data from tagger
# 1829
# Got data from tagger
# 1830
# Got data from tagger
# 1831
# Got data from tagger
# 1832
# Got data from tagger
# 1833
# Got data from tagger
# 1834
# Got data from tagger
# 1835
# Got data from tagger
# 1836
# Got data from tagger
# 1837
# Got data from tagger
# 1838
# Got data from tagger
# 1839
# Got data from tagger
# 1840
# Got data from tagger
# 1841
# Got data from tagger
# 1842
# Got data from tagger
# 1843
# Got data from tagger
# 1844
# Got data from tagger
# 1845
# Got data from tagger
# 1846
# Got data from tagger
# 1847
# Got data from tagger
# 1848
# Got data from tagger
# 1849
# Got data from tagger
# 1850
# Got data from tagger
# 1851
# Got data from tagger
# 1852
# Got data from tagger
# 1853
# Got data from tagger
# 1854
# Got data from tagger
# 1855
# Got data from tagger
# 1856
# Got data from tagger
# 1857
# Got data from tagger
# 1858
# Got data from tagger
# 1859
# Got data from tagger
# 1860
# Got data from tagger
# 1861
# Got data from tagger
# 1862
# Got data from tagger
# 1863
# Got data from tagger
# 1864

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred, average='macro')}")
print(f"Precision: {precision_score(y_test, y_pred, average='macro')}")
print(f"FMeasure: {f1_score(y_test, y_pred, average='macro')}")
# Out:
# Accuracy: 0.38873994638069703
# Recall: 0.3503708386268322
# Precision: 0.3699442676891407
# FMeasure: 0.2993974681709537
# /home/witold/anaconda3/envs/tf_pwr/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/witold/anaconda3/envs/tf_pwr/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Badania skuteczności predykcji w zależności od zastosowanego taggera i wybranych części mowy

# %%
import time
import pandas as pd

from sklearn.metrics import accuracy_score
from clarin_api_wrapper.krnnt_api_wrapper import KRNNTWrapper
from clarin_api_wrapper.morphodita_wrapper import MorphoditaWrapper
from clarin_api_wrapper.wcrft2_wrapper import Wcrft2Wrapper
from data_loader import load_tagger_preprocesses_json_file, load_polemo_no_segm_file, load_train_test_idx_file
from sentiment_model.sentiment_model import SentimentModel
from settings import PATH_TO_DATA

# %%
def find_idx_with_tag(data, tags):

    idx = []

    for i in range(0, len(data)):
        found = False
        for token in data[i]:
            if any(tag in token['lex']['ctag'] for tag in tags):
                found = True

        if found:
            idx.append(i)

    return idx


def get_tagger_class(name):
    if name == "krnnt":
        return KRNNTWrapper
    if name == "morphodita":
        return MorphoditaWrapper
    if name == "wcrft2":
        return Wcrft2Wrapper

def do_research():
    taggers = ["krnnt", "morphodita", "wcrft2"]
    parts_of_speech = ["verb", "noun", "adj", None]     # None for all parts of speech
    results = pd.DataFrame(columns=["tagger", "part_of_speech", "accuracy", "time"])
    for tagger in taggers:
        for part_of_speech in parts_of_speech:
            acc, time = do_reasearch_for_one_case(tagger, part_of_speech)
            part_of_speech_str = part_of_speech if part_of_speech is not None else "all"
            row = pd.DataFrame([{"tagger": tagger,
                                 "part_of_speech": part_of_speech,
                                 "accuracy": acc,
                                 "time": time}])
            results = results.append(row, ignore_index=True)
            results.to_csv(f"{PATH_TO_DATA}/results/{tagger}-{part_of_speech_str}.csv")

def do_reasearch_for_one_case(tagger, part_of_speech):
    train_data = load_polemo_no_segm_file("plemo2.0-no-segm.txt")
    preprocessed_data = load_tagger_preprocesses_json_file(
        f"{PATH_TO_DATA}/taggers_output/{tagger}/plemo_no_segm_data.json")
    train_idx, test_idx = load_train_test_idx_file(f"{PATH_TO_DATA}/train_test_idx.pkl")
    x_data, y_data = train_data.values[:, 0], train_data.values[:, 1].astype(int)

    x_train, y_train = preprocessed_data[train_idx], y_data[train_idx]
    x_test, y_test = preprocessed_data[test_idx], y_data[test_idx]

    preprocessed_train, preprocessed_test = preprocessed_data[train_idx], preprocessed_data[test_idx]

    model = SentimentModel(tagger_wrapper=Wcrft2Wrapper())

    start = time.time()
    model.fit(preprocessed_train, y_train, part_of_speech=part_of_speech, tagger_preprocessed=True)
    elapsed = time.time() - start
    y_pred = model.predict(preprocessed_test, part_of_speech=part_of_speech, tagger_preprocessed=True)

    acc = accuracy_score(y_test, y_pred)
    part_of_speech_str = part_of_speech if part_of_speech is not None else "all"
    print("Tagger: {} Part of speech: {} Accuracy: {}".format(tagger,
                                                              part_of_speech_str,
                                                              acc))
    return acc, elapsed

# %%
do_research()
# Out:
# (7459, 7083)
# Got lematized texts
# Tagger: krnnt Part of speech: verb Accuracy: 0.6386058981233244
# (7459, 24008)
# Got lematized texts
# Tagger: krnnt Part of speech: noun Accuracy: 0.6493297587131367
# (7459, 7128)
# Got lematized texts
# Tagger: krnnt Part of speech: adj Accuracy: 0.6605898123324396
# (7459, 39833)
# Got lematized texts
# Tagger: krnnt Part of speech: all Accuracy: 0.7233243967828418
# (7459, 5408)
# Got lematized texts
# Tagger: morphodita Part of speech: verb Accuracy: 0.6289544235924933
# (7459, 12397)
# Got lematized texts
# Tagger: morphodita Part of speech: noun Accuracy: 0.6353887399463807
# (7459, 4499)
# Got lematized texts
# Tagger: morphodita Part of speech: adj Accuracy: 0.6552278820375335
# (7459, 38831)
# Got lematized texts
# Tagger: morphodita Part of speech: all Accuracy: 0.7227882037533512
# (7459, 5212)
# Got lematized texts
# Tagger: wcrft2 Part of speech: verb Accuracy: 0.6209115281501341
# (7459, 12161)
# Got lematized texts
# Tagger: wcrft2 Part of speech: noun Accuracy: 0.6445040214477212
# (7459, 4352)
# Got lematized texts
# Tagger: wcrft2 Part of speech: adj Accuracy: 0.650402144772118
# (7459, 39526)
# Got lematized texts
# Tagger: wcrft2 Part of speech: all Accuracy: 0.7227882037533512

# %%
def compare_taggers(data, title):
    results = data.values
    labels = results[:, 0]
    accuracy = results[:, 2]
    
    fig = plt.figure(figsize=(15, 8))
    
    x_data = np.arange(len(labels))
    
    y_data = accuracy
    
    x = labels
    x_ticks = x_data
    plt.bar(x_data, accuracy, tick_label=labels)
    plt.title(title, fontsize=20)
    plt.ylabel("Accuracy")
    plt.xlabel("Taggers")
    
    xlocs, xlabs = plt.xticks()
    
    for i, v in enumerate(accuracy):
        plt.text(xlocs[i] - 0.10, v - 0.04, str(round(v, 5)), color='white', fontsize=15)
    
    plt.show()


def compare_part_of_speeches(data, title):
    results = data.values
    labels = results[:, 1]
    accuracy = results[:, 2]
    fig = plt.figure(figsize=(15, 8))
    
    x_data = np.arange(len(labels))
    
    y_data = accuracy
    
    x = labels
    x_ticks = x_data
    plt.bar(x_data, accuracy, tick_label=labels)
    plt.title(title, fontsize=20)
    plt.ylabel("Accuracy")
    plt.xlabel("Taggers")
    
    xlocs, xlabs = plt.xticks()
    
    for i, v in enumerate(accuracy):
        plt.text(xlocs[i] - 0.10, v - 0.04, str(round(v, 5)), color='white', fontsize=15)
    
    plt.show()
    



results = pd.read_csv(f"{PATH_TO_DATA}/results/wcrft2-all.csv", index_col=0).fillna("all")

# %%
compare_part_of_speeches(results[results['tagger'] == "krnnt"], "Tagger - krnnt")
compare_part_of_speeches(results[results['tagger'] == "morphodita"], "Tagger - morphodita")
compare_part_of_speeches(results[results['tagger'] == "wcrft2"], "Tagger - wcrft2")

# %%
compare_taggers(results[results['part_of_speech'] == "all"], "Part of speech - ALL")
compare_taggers(results[results['part_of_speech'] == "verb"], "Part of speech - Verbs")
compare_taggers(results[results['part_of_speech'] == "noun"], "Part of speech - Nouns")
compare_taggers(results[results['part_of_speech'] == "adj"], "Part of speech - Adj")

# %%
from tokenizer.tokenizer import Tokenizer
import data_loader as data_loader

dataset = data_loader.load_text_file("data_2.txt")
tokenizer = Tokenizer()
output = tokenizer.tokenize([dataset])


for sentence in output[0]:
    print(sentence)
# Out:
# ('Mój', 'def.')
# ('nowy', 'def.')
# ('adres', 'def.')
# ('e-mail', 'def.')
# ('to', 'def.')
# ('nazwa@domena.pl.', 'mail')

# %%
sentence = "Co rozkazał kpt. Witold?"
sentence1 = "Poproszę 2,5 kg. ziemniaków, tych które tak pieknie pachną"
sentence2 = "Pewne elementy tego sportu sięgają nawet II i III wieku p.n.e."

tokenizer = Tokenizer()
output = tokenizer.tokenize([sentence2])

output
# Out:
# [[('Pewne', 'def.'),
#   ('elementy', 'def.'),
#   ('tego', 'def.'),
#   ('sportu', 'def.'),
#   ('sięgają', 'def.'),
#   ('nawet', 'def.'),
#   ('II', 'def.'),
#   ('i', 'def.'),
#   ('III', 'def.'),
#   ('wieku', 'def.'),
#   ('przed_naszą_erą', 'short.'),
#   ('.', 'def.')]]

# %%
from clarin_api_wrapper.morfeusz_wrapper import MorfeuszWrapperLexeme

def print_analysis(analysis):
    for element in analysis:
        print(element)
        
morfeusz = MorfeuszWrapperLexeme()
analysed = morfeusz.analyse([sentence])

for word, analysis in analysed.items():
    print("{}:".format(word))
    print_analysis(analysis)
print()
# Out:
# Co rozkazał kpt. kucyk?:
# ['Co', 'company', 'brev:pun', [], []]
# ['Co', 'co:p', 'prep:acc', [], []]
# ['Co', 'co:p', 'prep:nom', [], []]
# ['Co', 'co:q', 'qub', [], []]
# ['Co', 'co:c', 'comp', [], []]
# ['Co', 'co:s', 'subst:sg:acc:n2', [], ['z_d.']]
# ['Co', 'co:s', 'subst:sg:gen:n2', [], ['rzad.']]
# ['Co', 'co:s', 'subst:sg:nom:n2', [], ['z_d.']]
# ['rozkazał', 'rozkazać', 'praet:sg:m1.m2.m3:perf', [], []]
# ['kpt', 'kapitan', 'brev:pun', [], []]
# ['.', '.', 'interp', [], []]
# ['kucyk', 'kucyk:s1', 'subst:sg:nom:m2', ['pospolita'], []]
# ['kucyk', 'kucyk:s2', 'subst:sg:acc:m3', ['pospolita'], []]
# ['kucyk', 'kucyk:s2', 'subst:sg:nom:m2', ['pospolita'], []]
# ['kucyk', 'kucyk:s2', 'subst:sg:nom:m3', ['pospolita'], []]
# ['?', '?', 'interp', [], []]

# %%
DEFAULT_TOKEN = "def."
MAIL_TOKEN = "mail"
DATE_TOKEN = "date"
SHORTCUT_TOKEN = "short."

tokenizer = Tokenizer()
output = tokenizer.tokenize([sentence])[0]
morfeusz = MorfeuszWrapperLexeme()

for word, tag in output:
    analysed = morfeusz.analyse([word])
    print("{}:".format(word))
    
    if tag == SHORTCUT_TOKEN:
        print([word.replace("_", " "), word.replace("_", " "), 'brev:pun', [], []])
    elif tag == DATE_TOKEN:
        print([word.replace("_", " "), word.replace("_", " "), 'subst:sg:nom:m2', [], []])
    elif tag == MAIL_TOKEN:
        print([word.replace("_", " "), word.replace("_", " "), 'subst:sg:nom:f', [], []])
    else:
        for word, analysis in analysed.items():
            print_analysis(analysis)
    print()
# Out:
# Co:
# ['Co', 'company', 'brev:pun', [], []]
# ['Co', 'co:p', 'prep:acc', [], []]
# ['Co', 'co:p', 'prep:nom', [], []]
# ['Co', 'co:q', 'qub', [], []]
# ['Co', 'co:c', 'comp', [], []]
# ['Co', 'co:s', 'subst:sg:acc:n2', [], ['z_d.']]
# ['Co', 'co:s', 'subst:sg:gen:n2', [], ['rzad.']]
# ['Co', 'co:s', 'subst:sg:nom:n2', [], ['z_d.']]
#
# rozkazał:
# ['rozkazał', 'rozkazać', 'praet:sg:m1.m2.m3:perf', [], []]
#
# kapitan:
# ['kapitan', 'kapitan', 'brev:pun', [], []]
#
# kucyk:
# ['kucyk', 'kucyk:s1', 'subst:sg:nom:m2', ['pospolita'], []]
# ['kucyk', 'kucyk:s2', 'subst:sg:acc:m3', ['pospolita'], []]
# ['kucyk', 'kucyk:s2', 'subst:sg:nom:m2', ['pospolita'], []]
# ['kucyk', 'kucyk:s2', 'subst:sg:nom:m3', ['pospolita'], []]
#
# ?:
# ['?', '?', 'interp', [], []]

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten, Conv2D
import tensorflow_datasets as tfds
from tensorflow.keras import Model

# %%
from tensorflow.compat.v1 import ConfigProto, GPUOptions
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
from sklearn.feature_extraction.text import CountVectorizer

model = SentimentModel(tagger_wrapper=Wcrft2Wrapper())
preprocessed_texts = model.preprocess_texts(preprocessed_train, part_of_speech=None, tagger_preprocessed=True)

vectorizer = CountVectorizer()
vectorizer.fit(preprocessed_texts)

X_train = vectorizer.transform(preprocessed_texts).toarray()
print(X_train.shape)
print(y_train.shape)

x_test = preprocessed_data[test_idx]

s_model = SentimentModel(tagger_wrapper=Wcrft2Wrapper())

x_test = s_model.preprocess_texts(x_test, part_of_speech=None, tagger_preprocessed=True)


x_test = vectorizer.transform(x_test).toarray()
# Out:
# (7459, 39833)
# (7459,)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
score = classifier.score(x_test, y_test)

print("Accuracy:", score)
# Out:
# /home/witold/anaconda3/envs/tf_pwr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/witold/anaconda3/envs/tf_pwr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy: 0.7120643431635388

# %%
input_dim = X_train.shape[1]  # Number of features

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1024, input_dim=input_dim, activation='relu'))
model.add(tf.keras.layers.Dense(1024, activation='relu'))
model.add(tf.keras.layers.Dense(1024, activation='relu'))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dense(6, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=5,
                    verbose=True,
                    validation_data=(x_test, y_test),
                    batch_size=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              40790016
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 43,809,542
# Trainable params: 43,809,542
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7459 samples, validate on 1865 samples
# Epoch 1/5
# 5440/7459 [====================>.........] - ETA: 2s - loss: 1.0980 - accuracy: 0.6320

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred, average='macro')}")
print(f"Precision: {precision_score(y_test, y_pred, average='macro')}")
print(f"FMeasure: {f1_score(y_test, y_pred, average='macro')}")
